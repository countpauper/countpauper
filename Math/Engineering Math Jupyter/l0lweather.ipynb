# %%
# https://www.youtube.com/watch?v=K-8F_zDMDUI&list=PLMrJAkhIeNNTYaOnVI3QpH7jgULnAmvPA&index=3
print("test")
# Out:
# test

# %%
a=np.array(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6d93b883c120> in <module>
# ----> 1 a=np.array(1)
#
# NameError: name 'np' is not defined

# %%
import numpy as np
a=np.array((1,2))
print(a)
# Out:
# [1 2]
