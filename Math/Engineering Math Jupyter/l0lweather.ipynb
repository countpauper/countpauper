# %%
# https://www.youtube.com/watch?v=K-8F_zDMDUI&list=PLMrJAkhIeNNTYaOnVI3QpH7jgULnAmvPA&index=3
print("test")
# Out:
# test

# %%
import numpy as np
a=np.array(1)

# %%
import numpy as np
a=np.array((1,2))
print(a)
# Out:
# [1 2]
