# %%
import numpy as np
from matplotlib import pyplot as plt

def taylor_sin(x, terms=9):
    return np.polyval([(1 if i%4==1 else -1)/np.math.factorial(i)  if (i%2) else 0 for i in range(terms, -1, -1)], x)
    return sum(-1**n for n in range(0,terms))

plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.grid(True)

x=np.linspace(-10, 10, 100)
plt.plot(x, np.sin(x), 'k', linewidth=2)
y = taylor_sin(x)
print(y)
plt.plot(x, taylor_sin(x), 'g--', linewidth=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-f4dc33ebd9e7> in <module>
#      12 x=np.linspace(-10, 10, 100)
#      13 plt.plot(x, np.sin(x), 'k', linewidth=2)
# ---> 14 y = taylor_sin(x)
#      15 print(y)
#      16 plt.plot(x, taylor_sin(x), 'g--', linewidth=2)
#
# <ipython-input-25-f4dc33ebd9e7> in taylor_sin(x, terms)
#       3
#       4 def taylor_sin(x, terms=9):
# ----> 5     return np.polyval([(1 if i%4==1 else -1)/factorial(i)  if (i%2) else 0 for i in range(terms, -1, -1)], x)
#       6     return sum(-1**n for n in range(0,terms))
#       7
#
# <ipython-input-25-f4dc33ebd9e7> in <listcomp>(.0)
#       3
#       4 def taylor_sin(x, terms=9):
# ----> 5     return np.polyval([(1 if i%4==1 else -1)/factorial(i)  if (i%2) else 0 for i in range(terms, -1, -1)], x)
#       6     return sum(-1**n for n in range(0,terms))
#       7
#
# NameError: name 'factorial' is not defined
